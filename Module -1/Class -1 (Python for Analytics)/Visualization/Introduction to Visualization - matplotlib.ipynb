# %% [markdown]
# # Basic of Visulization with Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
data=np.random.randn(50,).cumsum()

# %%
ax1.plot(data, 'k--')

# %%
ax2.plot(data, "r-")
ax3.plot(data, "b.")

# %% [markdown]
# ## Color, Markings, and Line Styles

# %%
x=[1,2,3,4,5]
y=[10,11,12,13,14]

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# Out:
# <img src="data:," width="0">

# %%
ax.plot(x, y, 'r--')

# %%
ax.plot(x, y, linestyle='--', color='r')

# %%
plt.plot?

# %%
plt.plot(data, 'ko--')

# %%
# %matplotlib inline

# %%
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data, 
         'k-', 
         drawstyle='steps-post', 
         label='Stepwise')

# %%
plt.plot(data, 'k-', 
         drawstyle='steps-post', 
         label='Stepwise')
plt.legend(loc='best')

# %% [markdown]
# ## Thickness, Label and Legend

# %%
# %matplotlib notebook

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
ax = fig.add_subplot(1, 1, 1)

# %%
ax.plot(data)

# %%
location=ax.set_xticks([0,10,20,30,40,50])
label=ax.set_xticklabels(
    ["one","two","three","four","five","six"],
    rotation=30,
    fontsize="small")

# %%
ax.set_title('First Graph')
# Out:
# Text(0.5, 1.0, 'First Graph')

# %%
ax.set_xlabel('Stages')
ax.set_ylabel('Anything')
# Out:
# Text(53.04166975286272, 0.5, 'Anything')

# %%
feature={"title":"Perfect Graph", 
         "xlabel":"Steps", 
         "ylabel":"Numbers"}

# %%
ax.set(**feature)
# Out:
# [Text(0.5, 1.0, 'Perfect Graph'),
#  Text(0.5, 14.395312797638294, 'Steps'),
#  Text(53.04166975286272, 0.5, 'Numbers')]

# %% [markdown]
# ## Adding Legends

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
ax=fig.add_subplot(1,1,1)

# %%
data1=np.random.randn(1000).cumsum()
data2=np.random.randn(1000).cumsum()
data3=np.random.randn(1000).cumsum()

# %%
ax.plot(data1, 'k', label='one')
ax.plot(data2, 'b--', label='two')
ax.plot(data3, 'r.', label='three')

# %%
ax.legend()

# %% [markdown]
# ## Saving Plots to File

# %%
plt.savefig("my-graph.pdf")

# %%
plt.savefig("my-graph.png")

# %%
plt.savefig("my-graph.png", dpi=500)

# %%
plt.savefig("my-graph.png", 
            dpi=500, 
            bbox_inches="tight")

# %% [markdown]
# End of code
